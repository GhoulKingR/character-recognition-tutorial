# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img = cv2.imread('./image.jpg', cv2.IMREAD_COLOR)
img
# Out:
# array([[[ 38,  95, 126],
#         [ 38,  95, 126],
#         [ 39,  96, 127],
#         ...,
#         [ 56, 111, 138],
#         [ 57, 112, 139],
#         [ 58, 113, 140]],
#
#        [[ 38,  95, 126],
#         [ 38,  95, 126],
#         [ 39,  96, 127],
#         ...,
#         [ 56, 111, 138],
#         [ 57, 112, 139],
#         [ 58, 113, 140]],
#
#        [[ 38,  95, 126],
#         [ 38,  95, 126],
#         [ 39,  96, 127],
#         ...,
#         [ 57, 112, 139],
#         [ 57, 112, 139],
#         [ 57, 112, 139]],
#
#        ...,
#
#        [[ 88, 106, 135],
#         [ 87, 105, 134],
#         [ 91, 109, 138],
#         ...,
#         [114, 172, 201],
#         [114, 172, 201],
#         [114, 172, 201]],
#
#        [[ 92, 110, 139],
#         [ 91, 109, 138],
#         [ 93, 111, 140],
#         ...,
#         [115, 173, 202],
#         [115, 173, 202],
#         [115, 173, 202]],
#
#        [[ 96, 114, 143],
#         [ 97, 115, 144],
#         [ 97, 115, 144],
#         ...,
#         [116, 174, 203],
#         [116, 174, 203],
#         [116, 174, 203]]], dtype=uint8)

# %%
img.shape
# Out:
# (4032, 3024, 3)

# %%
plt.imshow(img)

# %%
rgb_version = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_version)

# %%
plt.imshow(cv2.resize(rgb_version, (128, 128)))
